# %%
import numpy as np

# %%
import time

# %%
list_1 = [i for i in range(100000)]
list_2 = [j**2 for j in range(100000)]

# %%
t0 = time.time()
product_list = list(map(lambda x,y: x*y,list_1,list_2))
t1 = time.time()
list_time = t1-t0
print(list_time)
# Out:
# 0.03643202781677246

# %%
np_list_1 = np.array(list_1)
np_list_2 = np.array(list_2)

# %%
time0 = time.time()
product_result = np_list_1 * np_list_2
time1 = time.time()
list_time_2 = t1-t0
print(list_time_2)
# Out:
# 0.03643202781677246
