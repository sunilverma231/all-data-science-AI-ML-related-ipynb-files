# %%
import pandas as pd
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#
# ModuleNotFoundError: No module named 'pandas'

# %%
dib = pd.read_csv('Diabetes Example Data.csv')

# %%
dib.head()
# Out:
#    Blood Sugar Level Diabetes
# 0                190       No
# 1                240      Yes
# 2                300      Yes
# 3                160       No
# 4                200      Yes

# %%
# Converting Yes to 1 and No to 0
dib['Diabetes'] = dib['Diabetes'].map({'Yes': 1, 'No': 0})

# %%
dib.head()
# Out:
#    Blood Sugar Level  Diabetes
# 0                190         0
# 1                240         1
# 2                300         1
# 3                160         0
# 4                200         1

# %%
# Putting feature variable to X
X = dib['Blood Sugar Level']

# Putting response variable to y
y = dib['Diabetes']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Putting feature variable to X
# ----> 2 X = dib['Blood Sugar Level']
#       4 # Putting response variable to y
#       5 y = dib['Diabetes']
#
# NameError: name 'dib' is not defined

# %%
import statsmodels.api as sm

# %%
logm1 = sm.GLM(y,(sm.add_constant(X)), family = sm.families.Binomial())
logm1.fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:               Diabetes   No. Observations:                   10
# Model:                            GLM   Df Residuals:                        8
# Model Family:                Binomial   Df Model:                            1
# Link Function:                  logit   Scale:                             1.0
# Method:                          IRLS   Log-Likelihood:                -2.5838
# Date:                Tue, 06 Mar 2018   Deviance:                       5.1676
# Time:                        00:56:36   Pearson chi2:                     4.32
# No. Iterations:                     7
# ...
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const               -13.5243      9.358     -1.445      0.148     -31.866       4.817
# ...

# %%
documents = [
    "Vapour, Bangalore has a really great terrace seating and an awesome view of the Bangalore skyline",
    "The beer at Vapour, Bangalore was amazing. My favourites are the wheat beer and the ale beer.",
    "Vapour, Bangalore has the best view in Bangalore."
]

# Preprocess the documents by removing stopwords and punctuation
def preprocess(text):
    # Convert to lowercase
    text = text.lower()
    # Remove punctuation
    text = text.translate(str.maketrans('', '', string.punctuation))
    # Tokenize the text
    tokens = text.split()
    # Remove stopwords
    tokens = [token for token in tokens if token not in stopwords.words('english')]
    # Join the tokens back into a string
    preprocessed_text = ' '.join(tokens)
    return preprocessed_text

# Apply preprocessing to the documents
preprocessed_documents = [preprocess(doc) for doc in documents]

# Create the TF-IDF vectorizer
vectorizer = TfidfVectorizer()

# Fit the vectorizer on the preprocessed documents
tfidf_matrix = vectorizer.fit_transform(preprocessed_documents)

# Get the feature names (terms)
feature_names = vectorizer.get_feature_names()

# Find the index of the term 'Bangalore' in the feature names
term_index = feature_names.index('bangalore')

# Get the tf-idf score of the term 'Bangalore' in Document 1
tfidf_score = tfidf_matrix[0, term_index]

# Print the tf-idf score
print(tfidf_score)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/9m/ztkm5bns0x1b521x6wdpd4640000gn/T/ipykernel_16531/1876929085.py in <module>
#      20
#      21 # Apply preprocessing to the documents
# ---> 22 preprocessed_documents = [preprocess(doc) for doc in documents]
#      23
#      24 # Create the TF-IDF vectorizer
#
# /var/folders/9m/ztkm5bns0x1b521x6wdpd4640000gn/T/ipykernel_16531/1876929085.py in <listcomp>(.0)
#      20
#      21 # Apply preprocessing to the documents
# ---> 22 preprocessed_documents = [preprocess(doc) for doc in documents]
#      23
#      24 # Create the TF-IDF vectorizer
#
# /var/folders/9m/ztkm5bns0x1b521x6wdpd4640000gn/T/ipykernel_16531/1876929085.py in preprocess(text)
#      10     text = text.lower()
#      11     # Remove punctuation
# ---> 12     text = text.translate(str.maketrans('', '', string.punctuation))
# ...
