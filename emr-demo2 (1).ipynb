# %%
from pyspark.sql import SparkSession
# Out:
# VBox()
# Starting Spark application
# <table>
# <tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>User</th><th>Current session?</th></tr><tr><td>1</td><td>application_1693025035100_0002</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-172-31-6-190.ec2.internal:20888/proxy/application_1693025035100_0002/" class="emr-proxy-link" emr-resource="j-1EA1QQ0GWD49C
# " application-id="application_1693025035100_0002">Link</a></td><td><a target="_blank" href="http://ip-172-31-6-190.ec2.internal:8042/node/containerlogs/container_1693025035100_0002_01_000001/livy" >Link</a></td><td>None</td><td>✔</td></tr></table>
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# SparkSession available as 'spark'.
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
spark  = SparkSession.builder.appName("test").getOrCreate()
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…

# %%
spark.read.csv("s3://vbajaj-test/test.csv").show()
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +---+----+
# |_c0| _c1|
# +---+----+
# | id|name|
# |  1|   a|
# |  2|   b|
# +---+----+

# %%
spark.read.csv("s3://vbajaj/e-DTBNT8L8FN802GQCB60LYCSQM/Coaches.csv").show()
# Out:
# VBox()
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# +--------------------+--------------------+-----------------+--------+
# |                 _c0|                 _c1|              _c2|     _c3|
# +--------------------+--------------------+-----------------+--------+
# |                Name|                 NOC|       Discipline|   Event|
# |     ABDELMAGID Wael|               Egypt|         Football|    null|
# |           ABE Junya|               Japan|       Volleyball|    null|
# |       ABE Katsuhiko|               Japan|       Basketball|    null|
# |        ADAMA Cherif|       C�te d'Ivoire|         Football|    null|
# |          AGEBA Yuya|               Japan|       Volleyball|    null|
# |AIKMAN Siegfried ...|               Japan|           Hockey|     Men|
# |       AL SAADI Kais|             Germany|           Hockey|     Men|
# |       ALAMEDA Lonni|              Canada|Baseball/Softball|Softball|
# ...
