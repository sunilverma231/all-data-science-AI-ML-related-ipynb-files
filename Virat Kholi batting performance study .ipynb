# %%
import pandas as pd 
vf = pd.read_csv("virat.csv")
vf
# Out:
#     Runs Mins   BF  4s  6s      SR  Pos Dismissal  Inns     Opposition  \
# 0     12   33   22   1   0   54.54    2       lbw     1    v Sri Lanka
# 1     37   82   67   6   0   55.22    2    caught     2    v Sri Lanka
# 2     25   40   38   4   0   65.78    1   run out     1    v Sri Lanka
# 3     54   87   66   7   0   81.81    1    bowled     1    v Sri Lanka
# 4     31   45   46   3   1   67.39    1       lbw     2    v Sri Lanka
# ..   ...  ...  ...  ..  ..     ...  ...       ...   ...            ...
# 127   45   64   51   2   1   88.23    3    caught     2  v New Zealand
# 128   65  152   76   2   1   85.52    3    caught     1  v New Zealand
# 129  122  147  105   8   5  116.19    3    caught     2      v England
# 130    8    6    5   2   0     160    3    caught     1      v England
# 131   55   81   63   8   0    87.3    3    caught     2      v England
#
#             Ground Start Date
# 0         Dambulla  18-Aug-08
# 1         Dambulla  20-Aug-08
# ...

# %%
vf.head()
# Out:
#   Runs Mins  BF  4s  6s     SR  Pos Dismissal  Inns   Opposition  \
# 0   12   33  22   1   0  54.54    2       lbw     1  v Sri Lanka
# 1   37   82  67   6   0  55.22    2    caught     2  v Sri Lanka
# 2   25   40  38   4   0  65.78    1   run out     1  v Sri Lanka
# 3   54   87  66   7   0  81.81    1    bowled     1  v Sri Lanka
# 4   31   45  46   3   1  67.39    1       lbw     2  v Sri Lanka
#
#           Ground Start Date
# 0       Dambulla  18-Aug-08
# 1       Dambulla  20-Aug-08
# 2  Colombo (RPS)  24-Aug-08
# 3  Colombo (RPS)  27-Aug-08
# 4  Colombo (RPS)  29-Aug-08

# %%
vf.shape
# Out:
# (132, 12)

# %%
vf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132 entries, 0 to 131
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Runs        132 non-null    object
#  1   Mins        132 non-null    object
#  2   BF          132 non-null    int64
#  3   4s          132 non-null    int64
#  4   6s          132 non-null    int64
#  5   SR          132 non-null    object
#  6   Pos         132 non-null    int64
#  7   Dismissal   132 non-null    object
#  8   Inns        132 non-null    int64
#  9   Opposition  132 non-null    object
#  10  Ground      132 non-null    object
#  11  Start Date  132 non-null    object
# dtypes: int64(5), object(7)
# memory usage: 12.5+ KB

# %%
vf.describe()
# Out:
#                BF          4s          6s         Pos        Inns
# count  132.000000  132.000000  132.000000  132.000000  132.000000
# mean    50.871212    4.371212    0.545455    3.303030    1.575758
# std     38.729716    4.404032    1.086795    0.873174    0.496110
# min      0.000000    0.000000    0.000000    1.000000    1.000000
# 25%     17.750000    1.000000    0.000000    3.000000    1.000000
# 50%     42.500000    3.000000    0.000000    3.000000    2.000000
# 75%     82.250000    7.000000    1.000000    4.000000    2.000000
# max    140.000000   18.000000    7.000000    7.000000    2.000000

# %%
vf.dtypes
# Out:
# Runs          object
# Mins          object
# BF             int64
# 4s             int64
# 6s             int64
# SR            object
# Pos            int64
# Dismissal     object
# Inns           int64
# Opposition    object
# Ground        object
# Start Date    object
# dtype: object

# %%
vf["Runs"] = vf["Runs"].str.replace("*","").astype(int)
# Out:
# /var/folders/9m/ztkm5bns0x1b521x6wdpd4640000gn/T/ipykernel_67183/1387764723.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   vf["Runs"] = vf["Runs"].str.replace("*","").astype(int)

# %%
vf.dtypes
# Out:
# Runs           int64
# Mins          object
# BF             int64
# 4s             int64
# 6s             int64
# SR            object
# Pos            int64
# Dismissal     object
# Inns           int64
# Opposition    object
# Ground        object
# Start Date    object
# dtype: object

# %%
vf.Runs.plot.box()
# Out:
# <AxesSubplot:>

# %%
vf.Runs.describe()
# Out:
# count    132.000000
# mean      46.848485
# std       41.994635
# min        0.000000
# 25%       10.000000
# 50%       32.500000
# 75%       80.250000
# max      154.000000
# Name: Runs, dtype: float64

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 

df = pd.read_csv("virat.csv") 
df.head() 
df['Runs']= df['Runs'].apply(lambda x: int(x[:-1]) if x[-1]=="*" else int(x)) 
df['Runs'].describe(percentiles = [0.25,0.5,1])
# Out:
# count    132.000000
# mean      46.848485
# std       41.994635
# min        0.000000
# 25%       10.000000
# 50%       32.500000
# 100%     154.000000
# max      154.000000
# Name: Runs, dtype: float64

# %%
vf.head()
# Out:
#    Runs Mins  BF  4s  6s     SR  Pos Dismissal  Inns   Opposition  \
# 0    12   33  22   1   0  54.54    2       lbw     1  v Sri Lanka
# 1    37   82  67   6   0  55.22    2    caught     2  v Sri Lanka
# 2    25   40  38   4   0  65.78    1   run out     1  v Sri Lanka
# 3    54   87  66   7   0  81.81    1    bowled     1  v Sri Lanka
# 4    31   45  46   3   1  67.39    1       lbw     2  v Sri Lanka
#
#           Ground Start Date
# 0       Dambulla  18-Aug-08
# 1       Dambulla  20-Aug-08
# 2  Colombo (RPS)  24-Aug-08
# 3  Colombo (RPS)  27-Aug-08
# 4  Colombo (RPS)  29-Aug-08

# %%
vf["Date"] = pd.DatetimeIndex(vf["Start Date"]) 
vf.head()
# Out:
#    Runs Mins  BF  4s  6s     SR  Pos Dismissal  Inns   Opposition  \
# 0    12   33  22   1   0  54.54    2       lbw     1  v Sri Lanka
# 1    37   82  67   6   0  55.22    2    caught     2  v Sri Lanka
# 2    25   40  38   4   0  65.78    1   run out     1  v Sri Lanka
# 3    54   87  66   7   0  81.81    1    bowled     1  v Sri Lanka
# 4    31   45  46   3   1  67.39    1       lbw     2  v Sri Lanka
#
#           Ground Start Date       year       Date
# 0       Dambulla  18-Aug-08 2008-08-18 2008-08-18
# 1       Dambulla  20-Aug-08 2008-08-20 2008-08-20
# 2  Colombo (RPS)  24-Aug-08 2008-08-24 2008-08-24
# 3  Colombo (RPS)  27-Aug-08 2008-08-27 2008-08-27
# 4  Colombo (RPS)  29-Aug-08 2008-08-29 2008-08-29

# %%
vf["Year"] = pd.DatetimeIndex(vf["Date"])
vf.head()
# Out:
#    Runs Mins  BF  4s  6s     SR  Pos Dismissal  Inns   Opposition  \
# 0    12   33  22   1   0  54.54    2       lbw     1  v Sri Lanka
# 1    37   82  67   6   0  55.22    2    caught     2  v Sri Lanka
# 2    25   40  38   4   0  65.78    1   run out     1  v Sri Lanka
# 3    54   87  66   7   0  81.81    1    bowled     1  v Sri Lanka
# 4    31   45  46   3   1  67.39    1       lbw     2  v Sri Lanka
#
#           Ground Start Date       year       Date       Year
# 0       Dambulla  18-Aug-08 2008-08-18 2008-08-18 2008-08-18
# 1       Dambulla  20-Aug-08 2008-08-20 2008-08-20 2008-08-20
# 2  Colombo (RPS)  24-Aug-08 2008-08-24 2008-08-24 2008-08-24
# 3  Colombo (RPS)  27-Aug-08 2008-08-27 2008-08-27 2008-08-27
# 4  Colombo (RPS)  29-Aug-08 2008-08-29 2008-08-29 2008-08-29

# %%
vf.drop(["Year"],axis = 1, inplace = True)
vf.head()
# Out:
#    Runs Mins  BF  4s  6s     SR  Pos Dismissal  Inns   Opposition  \
# 0    12   33  22   1   0  54.54    2       lbw     1  v Sri Lanka
# 1    37   82  67   6   0  55.22    2    caught     2  v Sri Lanka
# 2    25   40  38   4   0  65.78    1   run out     1  v Sri Lanka
# 3    54   87  66   7   0  81.81    1    bowled     1  v Sri Lanka
# 4    31   45  46   3   1  67.39    1       lbw     2  v Sri Lanka
#
#           Ground Start Date       Date
# 0       Dambulla  18-Aug-08 2008-08-18
# 1       Dambulla  20-Aug-08 2008-08-20
# 2  Colombo (RPS)  24-Aug-08 2008-08-24
# 3  Colombo (RPS)  27-Aug-08 2008-08-27
# 4  Colombo (RPS)  29-Aug-08 2008-08-29

# %%
vf["Year"] = pd.DatetimeIndex(vf["Date"]).year
vf.head()
# Out:
#    Runs Mins  BF  4s  6s     SR  Pos Dismissal  Inns   Opposition  \
# 0    12   33  22   1   0  54.54    2       lbw     1  v Sri Lanka
# 1    37   82  67   6   0  55.22    2    caught     2  v Sri Lanka
# 2    25   40  38   4   0  65.78    1   run out     1  v Sri Lanka
# 3    54   87  66   7   0  81.81    1    bowled     1  v Sri Lanka
# 4    31   45  46   3   1  67.39    1       lbw     2  v Sri Lanka
#
#           Ground Start Date       Date  Year
# 0       Dambulla  18-Aug-08 2008-08-18  2008
# 1       Dambulla  20-Aug-08 2008-08-20  2008
# 2  Colombo (RPS)  24-Aug-08 2008-08-24  2008
# 3  Colombo (RPS)  27-Aug-08 2008-08-27  2008
# 4  Colombo (RPS)  29-Aug-08 2008-08-29  2008

# %%
vf["Date"] = pd.to_datetime(vf["Date"])
year = 2011 
event_11 = vf[vf["Date"].dt.year == year]
inning_11 = vf.groupby(["Year", "Runs"])
print(inning_11.sum())
# Out:
#             BF  4s  6s  Pos  Inns
# Year Runs
# 2008 12     22   1   0    2     1
#      25     38   4   0    1     1
#      31     46   3   1    1     2
#      37     67   6   0    2     2
#      54     66   7   0    1     1
# ...        ...  ..  ..  ...   ...
# 2016 117   117   7   2    3     1
#      154   134  16   1    3     2
# 2017 8       5   2   0    3     1
#      55     63   8   0    3     2
#      122   105   8   5    3     2
#
# [119 rows x 5 columns]

# %%
vf['Start Date']= vf['Start Date'].apply(lambda x: (x[-2:]))
# Out:
#    Runs Mins  BF  4s  6s     SR  Pos Dismissal  Inns   Opposition  \
# 0    12   33  22   1   0  54.54    2       lbw     1  v Sri Lanka
# 1    37   82  67   6   0  55.22    2    caught     2  v Sri Lanka
# 2    25   40  38   4   0  65.78    1   run out     1  v Sri Lanka
# 3    54   87  66   7   0  81.81    1    bowled     1  v Sri Lanka
# 4    31   45  46   3   1  67.39    1       lbw     2  v Sri Lanka
#
#           Ground Start Date       Date  Year
# 0       Dambulla         08 2008-08-18  2008
# 1       Dambulla         08 2008-08-20  2008
# 2  Colombo (RPS)         08 2008-08-24  2008
# 3  Colombo (RPS)         08 2008-08-27  2008
# 4  Colombo (RPS)         08 2008-08-29  2008

# %%
df['Start Date'].value_counts()
# Out:
# 18-Aug-08    1
# 16-Oct-13    1
# 27-Aug-14    1
# 26-Feb-14    1
# 31-Jan-14    1
#             ..
# 30-Mar-11    1
# 24-Mar-11    1
# 20-Mar-11    1
# 12-Mar-11    1
# 22-Jan-17    1
# Name: Start Date, Length: 132, dtype: int64

# %%
pd.pivot_table(df, values='score',columns=['year'], aggfunc=np.mean)
# Out:
# Start Date  1-Dec-10  10-Dec-10  11-Dec-11  11-Jan-10  11-Jan-13  11-Jun-11  \
# Runs              64          2         80        102         15          0
#
# Start Date  11-Oct-14  11-Oct-15  12-Feb-12  12-Jan-11  ...  6-Sep-11  \
# Runs               62         11         18         54  ...         9
#
# Start Date  7-Dec-10  7-Jan-10  8-Dec-11  8-Dec-13  8-Jun-11  8-Oct-14  \
# Runs               0        91        23         0        81         2
#
# Start Date  9-Mar-11  9-Nov-14  9-Sep-11
# Runs              12        53         7
#
# [1 rows x 132 columns]

# %%
pd.pivot_table(vf, values='score',columns=['year'], aggfunc=np.max)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/9m/ztkm5bns0x1b521x6wdpd4640000gn/T/ipykernel_67183/494120514.py in <module>
# ----> 1 pd.pivot_table(df, values='score',columns=['year'], aggfunc=np.max)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#      93         return table.__finalize__(data, method="pivot_table")
#      94
# ---> 95     table = __internal_pivot_table(
#      96         data,
#      97         values,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/pivot.py in __internal_pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#     139         for i in values:
#     140             if i not in data:
# ...

# %%
vf["Mins"]=vf["Mins"].apply(lambda x: int(x.replace('-','0')))

# %%
vf["Mins"].plot.hist(bins=1,range=[54.6,68])
vf["Mins"].plot.hist(bins=1,range=[68,81.4])
vf["Mins"].plot.hist(bins=1,range=[121.6,135])
# Out:
# <AxesSubplot:ylabel='Frequency'>
