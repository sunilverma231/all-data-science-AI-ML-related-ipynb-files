# %%
cars_per_cap = [809, 731, 588, 18, 200, 70, 45]
country = ['United States', 'Australia', 'Japan', 'India', 'Russia', 'Morocco', 'Egypt']
drives_right = [True, False, False, False, True, True, True]
import pandas as pd 
data = {"cars_per_cap": cars_per_cap, "country": country, "drives_right": drives_right}
data
# Out:
# {'cars_per_cap': [809, 731, 588, 18, 200, 70, 45],
#  'country': ['United States',
#   'Australia',
#   'Japan',
#   'India',
#   'Russia',
#   'Morocco',
#   'Egypt'],
#  'drives_right': [True, False, False, False, True, True, True]}

# %%
cars = pd.DataFrame(data)
cars
# Out:
#    cars_per_cap        country  drives_right
# 0           809  United States          True
# 1           731      Australia         False
# 2           588          Japan         False
# 3            18          India         False
# 4           200         Russia          True
# 5            70        Morocco          True
# 6            45          Egypt          True

# %%
type(cars)
# Out:
# pandas.core.frame.DataFrame

# %%
import pandas as pd 
cars_df = pd.read_csv("cars.csv")
cars_df
# Out:
#     USCA   US United States    809  FALSE
# 0  ASPAC  AUS     Australia  731.0   True
# 1  ASPAC  JAP         Japan  588.0   True
# 2  ASPAC   IN         India   18.0   True
# 3  ASPAC   RU        Russia  200.0  False
# 4  LATAM  MOR       Morocco   70.0  False
# 5    AFR   EG         Egypt   45.0  False
# 6    EUR  ENG       England    NaN   True

# %%
cars_df = pd.read_csv("cars.csv",header = None)
cars_df
# Out:
#        0    1              2      3      4
# 0   USCA   US  United States  809.0  False
# 1  ASPAC  AUS      Australia  731.0   True
# 2  ASPAC  JAP          Japan  588.0   True
# 3  ASPAC   IN          India   18.0   True
# 4  ASPAC   RU         Russia  200.0  False
# 5  LATAM  MOR        Morocco   70.0  False
# 6    AFR   EG          Egypt   45.0  False
# 7    EUR  ENG        England    NaN   True

# %%
cars_df.columns = ["Country code", "region", "country", "cars_per_cap", "dirve_right"]
cars_df.set_index(['region"'])
# Out:
#   File "/var/folders/9m/ztkm5bns0x1b521x6wdpd4640000gn/T/ipykernel_73505/1470876964.py", line 2
#     cars_df.set_index(['region','country_code', inplace = True])
#                                                         ^
# SyntaxError: invalid syntax

# %%
cars_df = pd.read_csv("cars.csv", header = None)
cars_df.columns = ["reqion", "country", "cars_per_cap", "drive_right"]
cars_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/9m/ztkm5bns0x1b521x6wdpd4640000gn/T/ipykernel_73505/106230777.py in <module>
#       1 cars_df = pd.read_csv("cars.csv", header = None)
# ----> 2 cars_df.columns = ["reqion", "country", "cars_per_cap", "drive_right"]
#       3 cars_df
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5586         try:
#    5587             object.__getattribute__(self, name)
# -> 5588             return object.__setattr__(self, name, value)
#    5589         except AttributeError:
#    5590             pass
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
# ...

# %%
cars.index.name = "country_code"
cars
# Out:
#              Country code region        country  cars_per_cap  dirve_right
# country_code
# 0                    USCA     US  United States         809.0        False
# 1                   ASPAC    AUS      Australia         731.0         True
# 2                   ASPAC    JAP          Japan         588.0         True
# 3                   ASPAC     IN          India          18.0         True
# 4                   ASPAC     RU         Russia         200.0        False
# 5                   LATAM    MOR        Morocco          70.0        False
# 6                     AFR     EG          Egypt          45.0        False
# 7                     EUR    ENG        England           NaN         True

# %%
cars_df.index.name = "country_code"
cars_df
# Out:
#              reqion        country  cars_per_cap  drive_right
# country_code
# USCA             US  United States         809.0        False
# ASPAC           AUS      Australia         731.0         True
# ASPAC           JAP          Japan         588.0         True
# ASPAC            IN          India          18.0         True
# ASPAC            RU         Russia         200.0        False
# LATAM           MOR        Morocco          70.0        False
# AFR              EG          Egypt          45.0        False
# EUR             ENG        England           NaN         True

# %%
cars_df = pd.read_csv("cars.csv",header = None)
cars_df.coloums = ['country_code',"region","country","cars_per_cap","drives_right"]
cars_df.set_index(["region", "country_code"], inplace = True) 
cars_df
# Out:
# /var/folders/9m/ztkm5bns0x1b521x6wdpd4640000gn/T/ipykernel_73505/1343647009.py:2: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   cars_df.coloums = ['country_code',"region","country","cars_per_cap","drives_right"]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/9m/ztkm5bns0x1b521x6wdpd4640000gn/T/ipykernel_73505/1343647009.py in <module>
#       1 cars_df = pd.read_csv("cars.csv",header = None)
#       2 cars_df.coloums = ['country_code',"region","country","cars_per_cap","drives_right"]
# ----> 3 cars_df.set_index(["region", "country_code"], inplace = True)
#       4 cars_df
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
# ...

# %%
cars_df = pd.read_csv("cars.csv")
cars_df
# Out:
#     USCA   US United States    809  FALSE
# 0  ASPAC  AUS     Australia  731.0   True
# 1  ASPAC  JAP         Japan  588.0   True
# 2  ASPAC   IN         India   18.0   True
# 3  ASPAC   RU        Russia  200.0  False
# 4  LATAM  MOR       Morocco   70.0  False
# 5    AFR   EG         Egypt   45.0  False
# 6    EUR  ENG       England    NaN   True

# %%
cars_df.columns = ["contry_code", "Region", "country","cars_per_caps","drive_right"]
cars_df
# Out:
#   contry_code Region    country  cars_per_caps  drive_right
# 0       ASPAC    AUS  Australia          731.0         True
# 1       ASPAC    JAP      Japan          588.0         True
# 2       ASPAC     IN      India           18.0         True
# 3       ASPAC     RU     Russia          200.0        False
# 4       LATAM    MOR    Morocco           70.0        False
# 5         AFR     EG      Egypt           45.0        False
# 6         EUR    ENG    England            NaN         True

# %%
cars_df = pd.read_csv("cars.csv", index_col = 0)
cars_df
# Out:
#         US United States    809  FALSE
# USCA
# ASPAC  AUS     Australia  731.0   True
# ASPAC  JAP         Japan  588.0   True
# ASPAC   IN         India   18.0   True
# ASPAC   RU        Russia  200.0  False
# LATAM  MOR       Morocco   70.0  False
# AFR     EG         Egypt   45.0  False
# EUR    ENG       England    NaN   True

# %%
import pandas as pd
marks = pd.read_csv("marks_1.csv",delimiter = "|", header = None, index_col = 0) 
marks.index.name = "S.No."
marks.columns = ["Name","Subject","Marks","Marks Obtained","Percentage"]
marks
# Out:
#           Name      Subject  Marks  Marks Obtained  Percentage
# S.No.
# 1       Akshay  Mathematics     50              40          80
# 2       Mahima      English     40              33          83
# 3        Vikas  Mathematics     50              42          84
# 4      Abhinav      English     40              31          78
# 5       Mahima      Science     50              40          80
# 6       Akshay      Science     50              49          98
# 7      Abhinav  Mathematics     50              47          94
# 8        Vikas      Science     50              40          80
# 9      Abhinav      Science     50              47          94
# 10       Vikas      English     40              39          98
# 11      Akshay      English     40              35          88
# 12      Mahima  Mathematics     50              43          86

# %%
#marks_df.header = ["Name", "Subject", "Maximum Marks", "Marks Obtained", "Percentage"]
marks_df.head()
# Out:
#   1|Akshay|Mathematics|50|40|80
# 0     2|Mahima|English|40|33|83
# 1  3|Vikas|Mathematics|50|42|84
# 2    4|Abhinav|English|40|31|78
# 3     5|Mahima|Science|50|40|80
# 4     6|Akshay|Science|50|49|98

# %%
marks_df = pd.read_csv(del)
marks_df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/9m/ztkm5bns0x1b521x6wdpd4640000gn/T/ipykernel_73505/1551517896.py in <module>
# ----> 1 marks_df = pd.marks_df(delimeter="|", index_col = 0 , header = None)
#       2 marks_df
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/__init__.py in __getattr__(name)
#     259         return _SparseArray
#     260
# --> 261     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     262
#     263
#
# AttributeError: module 'pandas' has no attribute 'marks_df'
