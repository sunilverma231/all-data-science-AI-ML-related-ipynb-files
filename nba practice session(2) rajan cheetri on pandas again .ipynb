# %%
import pandas as pd 
nba = pd.read_csv("nba.csv")
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
mycols = ["Name", "College"]
nba[mycols].head()
# Out:
#             Name            College
# 0  Avery Bradley              Texas
# 1    Jae Crowder          Marquette
# 2   John Holland  Boston University
# 3    R.J. Hunter      Georgia State
# 4  Jonas Jerebko                NaN

# %%
#filtering records

# %%
#find te players plying texas college

# %%
texasPlayers = nba.College == "Texas"
nba[texasPlayers]
# Out:
# Empty DataFrame
# Columns: [Name, Team, Number, Position, Age, Height, Weight, College, Salary]
# Index: []

# %%
texasPlayers = nba.Team == 'Toronto Raptors' 
nba[texasPlayers]
# Out:
#                  Name             Team  Number Position   Age Height  Weight  \
# 61    Bismack Biyombo  Toronto Raptors     8.0        C  23.0    6-9   245.0
# 62      Bruno Caboclo  Toronto Raptors    20.0       SF  20.0    6-9   205.0
# 63    DeMarre Carroll  Toronto Raptors     5.0       SF  29.0    6-8   212.0
# 64      DeMar DeRozan  Toronto Raptors    10.0       SG  26.0    6-7   220.0
# 65      James Johnson  Toronto Raptors     3.0       PF  29.0    6-9   250.0
# 66        Cory Joseph  Toronto Raptors     6.0       PG  24.0    6-3   190.0
# 67         Kyle Lowry  Toronto Raptors     7.0       PG  30.0    6-0   205.0
# 68     Lucas Nogueira  Toronto Raptors    92.0        C  23.0    7-0   220.0
# 69  Patrick Patterson  Toronto Raptors    54.0       PF  27.0    6-9   235.0
# 70      Norman Powell  Toronto Raptors    24.0       SG  23.0    6-4   215.0
# 71      Terrence Ross  Toronto Raptors    31.0       SF  25.0    6-7   195.0
# ...

# %%
#find players from "Texas" College Playing for "PG" Position 
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#    College     Salary
# 0     True  7730337.0
# 1    False  6796117.0
# 2    False        NaN

# %%
c1 = nba.College == "Texas"
c2 = nba.Position == "PG"
nba[c1 & c2]
# Out:
# Empty DataFrame
# Columns: [Name, Team, Number, Position, Age, Height, Weight, College, Salary]
# Index: []

# %%
c1 = nba.Age == 22 
c2 = nba.Weight >= 253 
nba[ c1 & c2 ]
# Out:
#                Name                   Team  Number Position   Age Height  \
# 128        Alex Len           Phoenix Suns    21.0        C  22.0    7-1
# 188  Andre Drummond        Detroit Pistons     0.0        C  22.0   6-11
# 412    Steven Adams  Oklahoma City Thunder    12.0        C  22.0    7-0
#
#      Weight  College     Salary
# 128   260.0    False  3807120.0
# 188   279.0    False  3272091.0
# 412   255.0    False  2279040.0

# %%
#Dealing wiht Nan in pandas

# %%
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#    College     Salary
# 0     True  7730337.0
# 1    False  6796117.0
# 2    False        NaN
# 3    False  1148640.0
# 4    False  5000000.0

# %%
#delting the rows with all the value with

# %%
nba = pd.read_csv("nba.csv")
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
round(nba.Salary.mean(),2)
# Out:
# 4842684.11

# %%
nba.Salary.fillna(round(nba.Salary.mean(),2) , inplace = True)

# %%
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College      Salary
# 0              Texas  7730337.00
# 1          Marquette  6796117.00
# 2  Boston University  4842684.11
# 3      Georgia State  1148640.00
# 4                NaN  5000000.00

# %%
nba.Salary.fillna(round(nba.College.mean(),2) , inplace = True)

# %%
nba.College.fillna("Others", inplace= True)
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College      Salary
# 0              Texas  7730337.00
# 1          Marquette  6796117.00
# 2  Boston University  4842684.11
# 3      Georgia State  1148640.00
# 4             Others  5000000.00

# %%
#data type conversion in padas

# %%
import pandas as pd
df = pd.read_csv("employees.csv")
df.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
df.dtypes
# Out:
# First Name            object
# Gender                object
# Start Date            object
# Last Login Time       object
# Salary                 int64
# Bonus %              float64
# Senior Management     object
# Team                  object
# dtype: object

# %%
df["Start Date"] = pd.to_datetime(df["Start Date"])

# %%
df.dtypes
# Out:
# First Name                   object
# Gender                       object
# Start Date           datetime64[ns]
# Last Login Time              object
# Salary                        int64
# Bonus %                     float64
# Senior Management            object
# Team                         object
# dtype: object

# %%
df['Last Login Time']= pd.to_datetime(df['Last Login Time'])
df.dtypes
# Out:
# First Name                   object
# Gender                       object
# Start Date           datetime64[ns]
# Last Login Time      datetime64[ns]
# Salary                        int64
# Bonus %                     float64
# Senior Management            object
# Team                         object
# dtype: object

# %%
df["Senior Management"] = df["Senior Management"].astype("bool")

# %%
df.dtypes
# Out:
# First Name                   object
# Gender                       object
# Start Date           datetime64[ns]
# Last Login Time      datetime64[ns]
# Salary                        int64
# Bonus %                     float64
# Senior Management              bool
# Team                         object
# dtype: object

# %%
#analytical function in padas

# %%
df.head()
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2023-01-29 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2023-01-29 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2023-01-29 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2023-01-29 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2023-01-29 16:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %%
df.Gender.nunique()
# Out:
# 2

# %%
#how many

# %%
df.Team.nunique()
# Out:
# 10

# %%
df.Gender.unique()
# Out:
# array(['Male', 'Female', nan], dtype=object)

# %%
df.Team.unique()
# Out:
# array(['Marketing', nan, 'Finance', 'Client Services', 'Legal', 'Product',
#        'Engineering', 'Business Development', 'Human Resources', 'Sales',
#        'Distribution'], dtype=object)

# %%
#How many males & females their??
# unique shows vallue what are present & count shows no of time values are present
df.Gender.value_counts()
# Out:
# Female    431
# Male      424
# Name: Gender, dtype: int64

# %%
df.Team.value_counts()
# Out:
# Client Services         106
# Finance                 102
# Business Development    101
# Marketing                98
# Product                  95
# Sales                    94
# Engineering              92
# Human Resources          91
# Distribution             90
# Legal                    88
# Name: Team, dtype: int64

# %%
#how many males & feamsle are working in Finance team???

# %%
finEmp = df.Team == "Finance"
finTeam = df[finEmp]
finTeam.Gender.value_counts()
# Out:
# Female    44
# Male      41
# Name: Gender, dtype: int64

# %%
#who is the most pad employee
hp = df.Salary == 
hp
# Out:
# 0       97308
# 1       61933
# 2      130590
# 3      138705
# 4      101004
#         ...
# 995    132483
# 996     42392
# 997     96914
# 998     60500
# 999    129949
# Name: Salary, Length: 1000, dtype: int64

# %%
Marketing = df.Team == "Marketing" 
SM = df["Senior Management"] == True 
newdf = df[Marketing & SM] 
newdf.sort_values (by = "Salary")
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 331     Evelyn  Female 1983-09-03 2023-01-29 13:58:00   36759   17.269
# 894      Betty  Female 2002-11-19 2023-01-29 10:40:00   37005    7.645
# 26       Craig    Male 2000-02-27 2023-01-29 07:45:00   37598    7.757
# 168      Peter     NaN 1987-09-03 2023-01-29 17:59:00   38989    7.017
# 617      Kathy  Female 2001-01-14 2023-01-29 05:11:00   45682    1.451
# 601  Christine     NaN 1980-06-15 2023-01-29 18:00:00   50366    9.862
# 659      Steve     NaN 2009-08-27 2023-01-29 15:41:00   53692    4.785
# 204     Willie    Male 2006-06-06 2023-01-29 09:45:00   55281    4.935
# 785        NaN  Female 1982-07-24 2023-01-29 00:00:00   57811    8.941
# 62         NaN  Female 2007-06-12 2023-01-29 17:25:00   58112   19.414
# 271      Frank     NaN 2001-11-20 2023-01-29 10:18:00   58563   12.062
# 327      Aaron    Male 1994-01-29 2023-01-29 18:48:00   58755    5.097
# ...

# %%
import pandas as pd
bond = pd.read_csv("jamesbond.csv")
bond
# Out:
#                                Film  Year           Actor            Director  \
# 0                            Dr. No  1962    Sean Connery       Terence Young
# 1             From Russia with Love  1963    Sean Connery       Terence Young
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 3                       Thunderball  1965    Sean Connery       Terence Young
# 4                     Casino Royale  1967     David Niven          Ken Hughes
# 5               You Only Live Twice  1967    Sean Connery       Lewis Gilbert
# 6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 7              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 8                  Live and Let Die  1973     Roger Moore        Guy Hamilton
# 9       The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# 10             The Spy Who Loved Me  1977     Roger Moore       Lewis Gilbert
# ...

# %%
#access rows using row indexes 
bond.iloc[2]
# Out:
# Film                   Goldfinger
# Year                         1964
# Actor                Sean Connery
# Director             Guy Hamilton
# Box Office                  820.4
# Budget                       18.6
# Bond Actor Salary             3.2
# Name: 2, dtype: object

# %%
bond.iloc[[2,5,7]]
# Out:
#                    Film  Year         Actor       Director  Box Office  \
# 2            Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
# 5   You Only Live Twice  1967  Sean Connery  Lewis Gilbert       514.2
# 7  Diamonds Are Forever  1971  Sean Connery   Guy Hamilton       442.5
#
#    Budget  Bond Actor Salary
# 2    18.6                3.2
# 5    59.9                4.4
# 7    34.7                5.8

# %%
bond.iloc[:3]
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2

# %%
bond.iloc[23:]
# Out:
#                  Film  Year         Actor      Director  Box Office  Budget  \
# 23  Quantum of Solace  2008  Daniel Craig  Marc Forster       514.2   181.4
# 24            Skyfall  2012  Daniel Craig    Sam Mendes       943.5   170.2
# 25            Spectre  2015  Daniel Craig    Sam Mendes       726.7   206.3
#
#     Bond Actor Salary
# 23                8.1
# 24               14.5
# 25                NaN

# %%
bond.head(3)
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2

# %%
bond.set_index("Film",inplace = True)

# %%
bond.head(3)
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
#
#                        Bond Actor Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2

# %%
#when we are using index other then row index use .loc
# Out:
#   File "/var/folders/9m/ztkm5bns0x1b521x6wdpd4640000gn/T/ipykernel_31051/1768953886.py", line 1
#     when we are using index other then row index use .loc
#          ^
# SyntaxError: invalid syntax

# %%
bond.loc["Goldfinger"]
# Out:
# Year                         1964
# Actor                Sean Connery
# Director             Guy Hamilton
# Box Office                  820.4
# Budget                       18.6
# Bond Actor Salary             3.2
# Name: Goldfinger, dtype: object

# %%
bond.reset_index(inplace = True)

# %%
bond.head()
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
# 3            Thunderball  1965  Sean Connery  Terence Young       848.1
# 4          Casino Royale  1967   David Niven     Ken Hughes       315.0
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2
# 3    41.9                4.7
# 4    85.0                NaN

# %%
bond.set_index("Year",inplace = True)
bond.head()
# Out:
#                        Film         Actor       Director  Box Office  Budget  \
# Year
# 1962                 Dr. No  Sean Connery  Terence Young       448.8     7.0
# 1963  From Russia with Love  Sean Connery  Terence Young       543.8    12.6
# 1964             Goldfinger  Sean Connery   Guy Hamilton       820.4    18.6
# 1965            Thunderball  Sean Connery  Terence Young       848.1    41.9
# 1967          Casino Royale   David Niven     Ken Hughes       315.0    85.0
#
#       Bond Actor Salary
# Year
# 1962                0.6
# 1963                1.6
# 1964                3.2
# 1965                4.7
# 1967                NaN

# %%
bond.loc[1985]
# Out:
# Film                 A View to a Kill
# Actor                     Roger Moore
# Director                    John Glen
# Box Office                      275.2
# Budget                           54.5
# Bond Actor Salary                 9.1
# Name: 1985, dtype: object

# %%
bond.reset_index(inplace = True)

# %%
fortune = pd.read_csv("fortune1000.csv", index_col = "Rank") 
fortune.head()
# Out:
#                  Company       Sector  \
# Rank
# 1                Walmart    Retailing
# 2            Exxon Mobil       Energy
# 3                  Apple   Technology
# 4     Berkshire Hathaway   Financials
# 5               McKesson  Health Care
#
#                                       Industry           Location  Revenue  \
# Rank
# 1                        General Merchandisers    Bentonville, AR   482130
# 2                           Petroleum Refining         Irving, TX   246204
# 3                  Computers, Office Equipment      Cupertino, CA   233715
# 4     Insurance: Property and Casualty (Stock)          Omaha, NE   210821
# 5                     Wholesalers: Health Care  San Francisco, CA   181241
#
#       Profits  Employees
# Rank
# 1       14694    2300000
# 2       16150      75600
# 3       53394     110000
# 4       24083     331000
# 5        1476      70400

# %%
fortune.shape
# Out:
# (1000, 7)

# %%
fortune.Sector.nunique()
# Out:
# 21

# %%
fortune.Sector.value_counts()
# Out:
# Financials                      139
# Energy                          122
# Technology                      102
# Retailing                        80
# Health Care                      75
# Business Services                51
# Industrials                      46
# Materials                        43
# Food, Beverages & Tobacco        43
# Wholesalers                      40
# Transportation                   36
# Chemicals                        30
# Household Products               28
# Engineering & Construction       26
# Media                            25
# Hotels, Resturants & Leisure     25
# Motor Vehicles & Parts           24
# Aerospace & Defense              20
# Telecommunications               15
# Apparel                          15
# Food and Drug Stores             15
# Name: Sector, dtype: int64

# %%
#Points to note
#There are 21 Groups(data frames ) inside secgrp objects 
#each group is named after

# %%
secGrp = fortune.groupby("Sector")

# %%
secGrp.get_group('Technology')['Profits'].sum()
# Out:
# 180473

# %%
secGrp.agg({"Revenue": "sum"})
# Out:
#                               Revenue
# Sector
# Aerospace & Defense            357940
# Apparel                         95968
# Business Services              272195
# Chemicals                      243897
# Energy                        1517809
# Engineering & Construction     153983
# Financials                    2217159
# Food and Drug Stores           483769
# Food, Beverages & Tobacco      555967
# Health Care                   1614707
# Hotels, Resturants & Leisure   169546
# Household Products             234737
# Industrials                    497581
# Materials                      259145
# Media                          220764
# Motor Vehicles & Parts         482540
# Retailing                     1465076
# Technology                    1377600
# Telecommunications             461834
# Transportation                 408508
# Wholesalers                    444800

# %%
secGrp.mean()
# Out:
#                                    Revenue      Profits     Employees
# Sector
# Aerospace & Defense           17897.000000  1437.100000  48402.850000
# Apparel                        6397.866667   549.066667  23093.133333
# Business Services              5337.156863   553.470588  26687.254902
# Chemicals                      8129.900000   754.266667  15455.033333
# Energy                        12441.057377  -602.024590   9745.303279
# Engineering & Construction     5922.423077   204.000000  15642.615385
# Financials                    15950.784173  1872.007194  24172.287770
# Food and Drug Stores          32251.266667  1117.266667  93026.533333
# Food, Beverages & Tobacco     12929.465116  1195.744186  28177.488372
# Health Care                   21529.426667  1414.853333  35710.520000
# Hotels, Resturants & Leisure   6781.840000   827.880000  99369.800000
# Household Products             8383.464286   515.285714  23072.785714
# ...
