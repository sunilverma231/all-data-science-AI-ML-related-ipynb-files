# %%
#Import the required Libraries.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings 
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Data Reading & Data Types

# %%
#Read the data in pandas
np0= pd.read_csv("Attribute+DataSet.csv")
np1= pd.read_csv("Dress+Sales.csv")

# %%
np0.head()
# Out:
#      Dress_ID    Style    Price  Rating Size  Season NeckLine SleeveLength  \
# 0  1006032852     Sexy      Low     4.6    M  Summer   o-neck    sleevless
# 1  1212192089   Casual      Low     0.0    L  Summer   o-neck        Petal
# 2  1190380701  vintage     High     0.0    L  Automn   o-neck         full
# 3   966005983    Brief  Average     4.6    L  Spring   o-neck         full
# 4   876339541     cute      Low     4.5    M  Summer   o-neck    butterfly
#
#         Material FabricType  Decoration Pattern Type  Recommendation
# 0            NaN    chiffon     ruffles       animal               1
# 1     microfiber        NaN     ruffles       animal               0
# 2       polyster        NaN         NaN        print               0
# 3           silk    chiffon  embroidary        print               1
# 4  chiffonfabric    chiffon         bow          dot               0

# %%
np0.Style.value_counts()
# Out:
# Casual      219
# Sexy         66
# party        51
# cute         44
# vintage      25
# bohemian     23
# Brief        17
# work         17
# sexy          7
# Novelty       6
# Flare         2
# OL            1
# fashion       1
# Name: Style, dtype: int64

# %%
np1.head()
# Out:
#        Dress_ID  29-08-2013  31-08-2013  09-02-2013  09-04-2013  09-06-2013  \
# 0  1.006033e+09        2114        2274        2491        2660        2727
# 1  1.212192e+09         151         275         570         750         813
# 2  1.190381e+09           6           7           7           7           8
# 3  9.660060e+08        1005        1128        1326        1455        1507
# 4  8.763395e+08         996        1175        1304        1396        1432
#
#    09-08-2013  09-10-2013  09-12-2013  14-09-2013  ...  20-09-2013  \
# 0        2887        2930      3119.0      3204.0  ...      3386.0
# 1        1066        1164      1558.0      1756.0  ...      2106.0
# 2           8           9        10.0        10.0  ...        10.0
# 3        1621        1637      1723.0      1746.0  ...      1812.0
# 4        1559        1570      1638.0      1655.0  ...      1824.0
#
#    22-09-2013  24-09-2013  28-09-2013  10-06-2013  10-12-2013  Spring  \
# ...

# %%
np1.columns
# Out:
# Index(['Dress_ID', '29-08-2013', '31-08-2013', '09-02-2013', '09-04-2013',
#        '09-06-2013', '09-08-2013', '09-10-2013', '09-12-2013', '14-09-2013',
#        '16-09-2013', '18-09-2013', '20-09-2013', '22-09-2013', '24-09-2013',
#        '26-09-2013', '28-09-2013', '30-09-2013', '10-02-2013', '10-04-2013',
#        '10-06-2013', '10-08-2013', '10-10-2013', '10-12-2013'],
#       dtype='object')

# %%
np0.describe()
# Out:
#            Dress_ID      Rating  Recommendation
# count  4.790000e+02  479.000000      479.000000
# mean   9.022420e+08    3.489353        0.427975
# std    1.822352e+08    2.028941        0.495302
# min    1.234568e+08    0.000000        0.000000
# 25%    7.666611e+08    2.000000        0.000000
# 50%    9.096250e+08    4.600000        0.000000
# 75%    1.039684e+09    4.800000        1.000000
# max    1.253973e+09    5.000000        1.000000

# %%
np0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 479 entries, 0 to 478
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Dress_ID        479 non-null    int64
#  1   Style           479 non-null    object
#  2   Price           477 non-null    object
#  3   Rating          479 non-null    float64
#  4   Size            479 non-null    object
#  5   Season          477 non-null    object
#  6   NeckLine        476 non-null    object
#  7   SleeveLength    477 non-null    object
#  8   Material        360 non-null    object
#  9   FabricType      223 non-null    object
#  10  Decoration      255 non-null    object
#  11  Pattern Type    377 non-null    object
#  12  Recommendation  479 non-null    int64
# dtypes: float64(1), int64(2), object(10)
# memory usage: 48.8+ KB

# %% [markdown]
# You have “Attribute DataSet” which contains a column named “Price”. Choose the correct statement from the following about its data type and variable type.
# - Integer type and numerical variable
# - Object type and categorical ordinal variable
# - Object type and categorical nominal variable
# - Float type and categorical variable.

# %% [markdown]
# There is another column in “Attribute DataSet” named as “Recommendation”, choose the correct statement about its data type and variable type.
# - Integer type and categorical
# - Object type and categorical
# - Integer type and continuous numerical
# - Object type only.

# %% [markdown]
# Which of the following column do you think are of no use in “Attribute DataSet”.
# - Dress_ID
# - Price
# - Size and material
# - NeckLine
# - None of the above

# %%
# Print the information about the attributes of inp0 and inp1.
print(np0.info())
print("\n")
print(np1.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 479 entries, 0 to 478
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Dress_ID        479 non-null    int64
#  1   Style           479 non-null    object
#  2   Price           477 non-null    object
#  3   Rating          479 non-null    float64
#  4   Size            479 non-null    object
#  5   Season          477 non-null    object
#  6   NeckLine        476 non-null    object
#  7   SleeveLength    477 non-null    object
#  8   Material        360 non-null    object
#  9   FabricType      223 non-null    object
#  10  Decoration      255 non-null    object
#  11  Pattern Type    377 non-null    object
#  12  Recommendation  479 non-null    int64
# dtypes: float64(1), int64(2), object(10)
# memory usage: 48.8+ KB
# None
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 479 entries, 0 to 478
# Data columns (total 24 columns):
# ...

# %% [markdown]
# ### Fixing the Rows and Columns

# %% [markdown]
# As you can see, there is a column in “Attribute Dataset” named as ‘Size’. This column contains the values in abbreviation format. Write a code in Python to convert the followings:
#
# - M into  “Medium”
# - L into  “Large”
# - XL into “Extra large”
# - free into “Free”
# - S, s & small into “Small”.
#
# Now once you are done with changes in the dataset, what is the value of the lowest percentage, the highest percentage and the percentage of Small size categories in the column named “Size”?

# %%
# Column fixing, correcting size abbreviation. count the percentage of each size category in "Size" column.
np0.Size.replace({"M": "Medium", "L": "Large","XL":"Extra Large", "free":"free", "S":"Small","s":"Small","small":"Small"},inplace = True)

# %%
# Print the value counts of each category in "Size" column.
np0.Size.value_counts()
# Out:
# Medium         171
# free           165
# Large           93
# Small           36
# Extra Large     14
# Name: Size, dtype: int64

# %%
#Print the value counts of each category in "Size" columns 
np0.Size.value_counts(normalize = True)*100
# Out:
# Medium         35.699374
# free           34.446764
# Large          19.415449
# Small           7.515658
# Extra Large     2.922756
# Name: Size, dtype: float64

# %%
#checking for the null data in both the frames and imputing the data 
np1.isnull().sum()
# Out:
# Dress_ID        0
# 29-08-2013      0
# 31-08-2013      0
# 09-02-2013      0
# 09-04-2013      0
# 09-06-2013      0
# 09-08-2013      0
# 09-10-2013      0
# 09-12-2013      0
# 14-09-2013      0
# 16-09-2013      0
# 18-09-2013      0
# 20-09-2013      0
# 22-09-2013      0
# 24-09-2013      0
# 26-09-2013    222
# 28-09-2013      0
# 30-09-2013    257
# 10-02-2013    259
# 10-04-2013    258
# 10-06-2013      0
# 10-08-2013    255
# 10-10-2013    255
# 10-12-2013      0
# dtype: int64

# %% [markdown]
# ### Impute/Remove Missing values
#
# You are given another dataset named “Dress Sales”. Now if you observe the datatypes of the columns using ‘inp1.info()’ command, you can identify that there are certain columns defined as object data type though they primarily consist of numeric data.
#
# Now if you try and convert these object data type columns into numeric data type(float), you will come across an error message. Try to correct this error.

# %%
# Try to convert the object type into float type of data. YOU GET ERROR MESSAGE.
np1['18-09-2013'][np1['18-09-2013']=='removed']
# Out:
# 263    removed
# Name: 18-09-2013, dtype: object

# %%
#do the reguired cahnges in the "Dress Salles" data set to get null values on string values 
np1.loc[np1['09-12-2013']== 'Removed',"09-12-2013"] = np.NaN

np1.loc[np1['14-09-2013']== 'removed',"14-09-2013"] = np.NaN

np1.loc[np1['16-09-2013']== 'removed',"16-09-2013"] = np.NaN

np1.loc[np1['18-09-2013']== 'removed',"18-09-2013"] = np.NaN

np1.loc[np1['20-09-2013']== 'removed',"20-09-2013"] = np.NaN

np1.loc[np1['22-09-2013']== 'Orders',"22-09-2013"] = np.NaN

# %%
#convert the object type clumns in "Dress Sales" into float type of data type 
np1['18-09-2013']=np1['18-09-2013'].astype(float)
np1['14-09-2013']=np1['14-09-2013'].astype(float)
np1['16-09-2013']=np1['16-09-2013'].astype(float)
np1['20-09-2013']=np1['20-09-2013'].astype(float)
np1['22-09-2013']=np1['22-09-2013'].astype(float)
np1['09-12-2013']=np1['09-12-2013'].astype(float)

# %%
np1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 479 entries, 0 to 478
# Data columns (total 24 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Dress_ID    479 non-null    float64
#  1   29-08-2013  479 non-null    int64
#  2   31-08-2013  479 non-null    int64
#  3   09-02-2013  479 non-null    int64
#  4   09-04-2013  479 non-null    int64
#  5   09-06-2013  479 non-null    int64
#  6   09-08-2013  479 non-null    int64
#  7   09-10-2013  479 non-null    int64
#  8   09-12-2013  478 non-null    float64
#  9   14-09-2013  478 non-null    float64
#  10  16-09-2013  478 non-null    float64
#  11  18-09-2013  478 non-null    float64
#  12  20-09-2013  478 non-null    float64
#  13  22-09-2013  478 non-null    float64
#  14  24-09-2013  479 non-null    int64
#  15  26-09-2013  257 non-null    float64
#  16  28-09-2013  479 non-null    int64
#  17  30-09-2013  222 non-null    float64
#  18  10-02-2013  220 non-null    float64
# ...

# %% [markdown]
# When you see the null counts in “Dress Sales” dataset after performing all the operations that have been mentioned in jupyter notebook, you will find that there are some columns in “Dress Sales” data where there are more than 40% of missing values. Based on your understanding of dealing with missing values do the following steps.

# %%
# Print the null percetange of each column of inp1.
np1.isnull().sum()/len(np1.index)*100
# Out:
# Dress_ID       0.000000
# 29-08-2013     0.000000
# 31-08-2013     0.000000
# 09-02-2013     0.000000
# 09-04-2013     0.000000
# 09-06-2013     0.000000
# 09-08-2013     0.000000
# 09-10-2013     0.000000
# 09-12-2013     0.208768
# 14-09-2013     0.208768
# 16-09-2013     0.208768
# 18-09-2013     0.208768
# 20-09-2013     0.208768
# 22-09-2013     0.208768
# 24-09-2013     0.000000
# 26-09-2013    46.346555
# 28-09-2013     0.000000
# 30-09-2013    53.653445
# 10-02-2013    54.070981
# 10-04-2013    53.862213
# 10-06-2013     0.000000
# 10-08-2013    53.235908
# 10-10-2013    53.235908
# 10-12-2013     0.000000
# dtype: float64

# %%
# Drop the columns in "Dress Sales" which have more than 40% of missing values.
np1 = np1.drop(['26-09-2013','30-09-2013','10-02-2013','10-04-2013','10-08-2013','10-10-2013' ],axis=1)
np1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 479 entries, 0 to 478
# Data columns (total 18 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Dress_ID    479 non-null    float64
#  1   29-08-2013  479 non-null    int64
#  2   31-08-2013  479 non-null    int64
#  3   09-02-2013  479 non-null    int64
#  4   09-04-2013  479 non-null    int64
#  5   09-06-2013  479 non-null    int64
#  6   09-08-2013  479 non-null    int64
#  7   09-10-2013  479 non-null    int64
#  8   09-12-2013  478 non-null    float64
#  9   14-09-2013  478 non-null    float64
#  10  16-09-2013  478 non-null    float64
#  11  18-09-2013  478 non-null    float64
#  12  20-09-2013  478 non-null    float64
#  13  22-09-2013  478 non-null    float64
#  14  24-09-2013  479 non-null    int64
#  15  28-09-2013  479 non-null    int64
#  16  10-06-2013  479 non-null    int64
#  17  10-12-2013  479 non-null    int64
# dtypes: float64(7), int64(11)
# ...

# %%
np1.isnull().sum()/len(np1.index)*100
# Out:
# Dress_ID      0.000000
# 29-08-2013    0.000000
# 31-08-2013    0.000000
# 09-02-2013    0.000000
# 09-04-2013    0.000000
# 09-06-2013    0.000000
# 09-08-2013    0.000000
# 09-10-2013    0.000000
# 09-12-2013    0.208768
# 14-09-2013    0.208768
# 16-09-2013    0.208768
# 18-09-2013    0.208768
# 20-09-2013    0.208768
# 22-09-2013    0.208768
# 24-09-2013    0.000000
# 28-09-2013    0.000000
# 10-06-2013    0.000000
# 10-12-2013    0.000000
# dtype: float64

# %%
np0.Season.value_counts()
# Out:
# Summer    154
# Spring    116
# Winter     94
# Automn     59
# winter     45
# Autumn      7
# spring      2
# Name: Season, dtype: int64

# %%
np1.columns
# Out:
# Index(['Dress_ID', '29-08-2013', '31-08-2013', '09-02-2013', '09-04-2013',
#        '09-06-2013', '09-08-2013', '09-10-2013', '09-12-2013', '14-09-2013',
#        '16-09-2013', '18-09-2013', '20-09-2013', '22-09-2013', '24-09-2013',
#        '28-09-2013', '10-06-2013', '10-12-2013'],
#       dtype='object')

# %% [markdown]
# You should categorise the dates into seasons in “Dress Sales” data to simplify the analysis according to the following criteria:
# - June, July and August: Summer.
# - September, October and November: Autumn.
# - December, January and February: WInter.
# - March, April and May: Spring.

# %%
# Create the four seasons columns in inp1, according to the above criteria.
Summer = (np1[['29-08-2013','31-08-2013','09-06-2013','09-08-2013', '10-06-2013']].sum()).sum()

Autumn = (np1[['09-10-2013', '14-09-2013','16-09-2013', '18-09-2013', '20-09-2013', '22-09-2013', '24-09-2013',
       '28-09-2013']].sum()).sum()

Winter = (np1[['09-02-2013','10-12-2013']].sum()).sum()

Spring = (np1['09-04-2013'].sum()).sum()

# %%
Summer
# Out:
# 691907

# %%
Autumn
# Out:
# 1363288.0

# %%
Winter
# Out:
# 314990

# %%
Spring
# Out:
# 143600

# %%
np1['Spring'] = np1.apply(lambda x: x['09-04-2013'], axis=1)

np1['Summer'] = np1.apply(lambda x: x['29-08-2013'] + x['31-08-2013']+ x['09-06-2013']+ x['09-08-2013']+ x['10-06-2013'], axis=1)

np1['Winter'] = np1.apply(lambda x: x['09-02-2013'] + x['09-12-2013']+ x['10-12-2013'], axis=1)

np1['Autumn'] = np1.apply(lambda x: x['09-10-2013'] + x['14-09-2013']+ x['16-09-2013']+ x['18-09-2013']+ x['20-09-2013']+ x['22-09-2013']+ x['24-09-2013']+ x['28-09-2013'], axis=1)

# %%
np0.head()
# Out:
#      Dress_ID    Style    Price  Rating    Size  Season NeckLine SleeveLength  \
# 0  1006032852     Sexy      Low     4.6  Medium  Summer   o-neck    sleevless
# 1  1212192089   Casual      Low     0.0   Large  Summer   o-neck        Petal
# 2  1190380701  vintage     High     0.0   Large  Automn   o-neck         full
# 3   966005983    Brief  Average     4.6   Large  Spring   o-neck         full
# 4   876339541     cute      Low     4.5  Medium  Summer   o-neck    butterfly
#
#         Material FabricType  Decoration Pattern Type  Recommendation
# 0            NaN    chiffon     ruffles       animal               1
# 1     microfiber        NaN     ruffles       animal               0
# 2       polyster        NaN         NaN        print               0
# 3           silk    chiffon  embroidary        print               1
# 4  chiffonfabric    chiffon         bow          dot               0

# %%
# calculate the sum of sales in each seasons in inp1 i.e. "Dress Sales".
np1.sum()
# Out:
# Dress_ID      4.321739e+11
# 29-08-2013    9.488300e+04
# 31-08-2013    1.004830e+05
# 09-02-2013    1.070810e+05
# 09-04-2013    1.436000e+05
# 09-06-2013    1.459730e+05
# 09-08-2013    1.516200e+05
# 09-10-2013    1.533280e+05
# 09-12-2013    1.596930e+05
# 14-09-2013    1.627920e+05
# 16-09-2013    1.653180e+05
# 18-09-2013    1.678330e+05
# 20-09-2013    1.723510e+05
# 22-09-2013    1.764140e+05
# 24-09-2013    1.786380e+05
# 28-09-2013    1.866140e+05
# 10-06-2013    1.989480e+05
# 10-12-2013    2.079090e+05
# Spring        1.436000e+05
# Summer        6.919070e+05
# Winter        4.736400e+05
# Autumn        1.353543e+06
# dtype: float64

# %% [markdown]
# Now let's merge inp1 with inp0 with left join manner, so that the information of inp0 should remain intact.

# %%
# Merge inp0 with inp1 into inp0. this is also called left merge.
np0 = pd.merge(left=np0,right=np1, how='left', left_on='Dress_ID', right_on='Dress_ID')
np0.head()
# Out:
#      Dress_ID    Style    Price  Rating    Size  Season NeckLine SleeveLength  \
# 0  1006032852     Sexy      Low     4.6  Medium  Summer   o-neck    sleevless
# 1  1212192089   Casual      Low     0.0   Large  Summer   o-neck        Petal
# 2  1190380701  vintage     High     0.0   Large  Automn   o-neck         full
# 3   966005983    Brief  Average     4.6   Large  Spring   o-neck         full
# 4   876339541     cute      Low     4.5  Medium  Summer   o-neck    butterfly
#
#         Material FabricType  ... 20-09-2013 22-09-2013  24-09-2013  \
# 0            NaN    chiffon  ...     3386.0     3479.0        3554
# 1     microfiber        NaN  ...     2106.0     2454.0        2710
# 2       polyster        NaN  ...       10.0       11.0          11
# 3           silk    chiffon  ...     1812.0     1845.0        1878
# 4  chiffonfabric    chiffon  ...     1824.0     1919.0        2032
#
#    28-09-2013  10-06-2013  10-12-2013  Spring   Summer  Winter   Autumn
# ...

# %%
np0.isnull().sum()
# Out:
# Dress_ID            0
# Style               0
# Price               2
# Rating              0
# Size                0
# Season              2
# NeckLine            3
# SleeveLength        2
# Material          119
# FabricType        256
# Decoration        224
# Pattern Type      102
# Recommendation      0
# 20-09-2013          1
# 22-09-2013          1
# 24-09-2013          0
# 28-09-2013          0
# 10-06-2013          0
# 10-12-2013          0
# Spring              0
# Summer              0
# Winter              1
# Autumn              2
# dtype: int64

# %%
# Now Drop the Date columns from inp0 as it is already combined into four seasons.
np0.drop(np0.loc[:,'20-09-2013' : '10-12-2013'].columns, axis= 1, inplace= True)

# %%
np0.head()
# Out:
#      Dress_ID    Style    Price  Rating    Size  Season NeckLine SleeveLength  \
# 0  1006032852     Sexy      Low     4.6  Medium  Summer   o-neck    sleevless
# 1  1212192089   Casual      Low     0.0   Large  Summer   o-neck        Petal
# 2  1190380701  vintage     High     0.0   Large  Automn   o-neck         full
# 3   966005983    Brief  Average     4.6   Large  Spring   o-neck         full
# 4   876339541     cute      Low     4.5  Medium  Summer   o-neck    butterfly
#
#         Material FabricType  Decoration Pattern Type  Recommendation  Spring  \
# 0            NaN    chiffon     ruffles       animal               1  2660.0
# 1     microfiber        NaN     ruffles       animal               0   750.0
# 2       polyster        NaN         NaN        print               0     7.0
# 3           silk    chiffon  embroidary        print               1  1455.0
# 4  chiffonfabric    chiffon         bow          dot               0  1396.0
#
#     Summer  Winter   Autumn
# ...

# %% [markdown]
# Print the null count of inp0 to get the idea about the missing values in data set.

# %%
# Print the null count of each columns in inp0 dataframe i.e. combined data frame of inp0 and inp1 without date columns.
np0.isnull().sum()
# Out:
# Dress_ID            0
# Style               0
# Price               2
# Rating              0
# Size                0
# Season              2
# NeckLine            3
# SleeveLength        2
# Material          119
# FabricType        256
# Decoration        224
# Pattern Type      102
# Recommendation      0
# Spring              0
# Summer              0
# Winter              1
# Autumn              2
# dtype: int64

# %% [markdown]
# You can see that there are two types of variables one with a large number of missing values and another is very less number of missing values. These two columns can be categorized as:
#
# Type-1: Missing values are very less (around 2 or 3 missing values): Price, Season, NeckLine, SleeveLength, Winter and Autumn.
#
# Type-2: Missing values are large in numbers (more than 15%): Material, FabricType, Decoration and Pattern Type.

# %%
# Deal with the missing values of Type-1 columns: Price, Season, NeckLine, SleeveLength, Winter and Autumn.
np0['Price'].fillna(np0['Price'].mode(), inplace=True)
np0['Season'].fillna(np0['Season'].mode(), inplace=True)
np0['NeckLine'].fillna(np0['NeckLine'].mode(), inplace=True)
np0['SleeveLength'].fillna(np0['SleeveLength'].mode(), inplace=True)
np0['Winter'].fillna(np0['Winter'].mode(), inplace=True)
np0['Autumn'].fillna(np0['Autumn'].mode(), inplace=True)

# %%
# Deal with the missing values for Type-2 columns: Material, FabricType, Decoration and Pattern Type.
np0['Material'].fillna(np0['Material'].mode(), inplace=True)
np0['FabricType'].fillna(np0['FabricType'].mode(), inplace=True)
np0['Decoration'].fillna(np0['Decoration'].mode(), inplace=True)
np0['Pattern Type'].fillna(np0['Pattern Type'].mode(), inplace=True)

# %%
np0.head()
# Out:
#      Dress_ID    Style    Price  Rating    Size  Season NeckLine SleeveLength  \
# 0  1006032852     Sexy      Low     4.6  Medium  Summer   o-neck    sleevless
# 1  1212192089   Casual      Low     0.0   Large  Summer   o-neck        Petal
# 2  1190380701  vintage     High     0.0   Large  Automn   o-neck         full
# 3   966005983    Brief  Average     4.6   Large  Spring   o-neck         full
# 4   876339541     cute      Low     4.5  Medium  Summer   o-neck    butterfly
#
#         Material FabricType  Decoration Pattern Type  Recommendation  Spring  \
# 0         cotton    chiffon     ruffles       animal               1  2660.0
# 1     microfiber        NaN     ruffles       animal               0   750.0
# 2       polyster        NaN         NaN        print               0     7.0
# 3           silk    chiffon  embroidary        print               1  1455.0
# 4  chiffonfabric    chiffon         bow          dot               0  1396.0
#
#     Summer  Winter   Autumn
# ...

# %% [markdown]
# ### Standardise value

# %% [markdown]
# In the given dataset, there are certain discrepancies with the categorical names such as irregular spellings. Choose the correct option of columns with irregular categories and update them.
#
# - Season, NeckLine
# - Price, Material
# - fabricType, Decoration
# - Season, SleeveLength

# %%
#correcting the spellings.
np0["Season"].unique()
# Out:
# array(['Summer', 'Automn', 'Spring', 'Winter', 'spring', 'winter', nan,
#        'Autumn'], dtype=object)

# %%
#correcting the Spellings.
np0["Season"].replace(["Automn","winter"],["Autumn","Winter"], inplace = True)
np0["Season"].unique
# Out:
# <bound method Series.unique of 0      Summer
# 1      Summer
# 2      Autumn
# 3      Spring
# 4      Summer
#         ...
# 474    Winter
# 475    Spring
# 476    Summer
# 477    Winter
# 478    Summer
# Name: Season, Length: 479, dtype: object>

# %%
np0["SleeveLength"].unique()
# Out:
# array(['sleevless', 'Petal', 'full', 'butterfly', 'short', 'threequarter',
#        'halfsleeve', 'cap-sleeves', 'turndowncollor', 'threequater',
#        'capsleeves', 'sleeveless', 'sleeevless', 'half', 'urndowncollor',
#        'thressqatar', nan, 'sleveless'], dtype=object)

# %%
np0["SleeveLength"].replace(["thressqatar"],["threequarter"],inplace = True)
np0["SleeveLength"].unique()
# Out:
# array(['sleevless', 'Petal', 'full', 'butterfly', 'short', 'threequarter',
#        'halfsleeve', 'cap-sleeves', 'turndowncollor', 'threequater',
#        'capsleeves', 'sleeveless', 'sleeevless', 'half', 'urndowncollor',
#        nan, 'sleveless'], dtype=object)

# %% [markdown]
# ## Univariate Analysis

# %% [markdown]
# ### Categorical Unordered Univariate Analysis

# %% [markdown]
# There is a column named ‘Style’ in ‘Attribute Dataset’ which consists of the different style categories of the women apparels. Certain categories whose total sale is less than 50000 across all the seasons is considered under one single category as ‘Others’.

# %% [markdown]
# Which of the following categories in ‘Style’ column can be grouped into ‘Others’ category? and perform the grouping operation in the notebook for further analysis.
# - Flare, fashion
# - Novelty, bohemian
# - OL, fashion, work
# - Novelty, fashion, Flare

# %%
np0.head(3)
# Out:
#      Dress_ID    Style Price  Rating    Size  Season NeckLine SleeveLength  \
# 0  1006032852     Sexy   Low     4.6  Medium  Summer   o-neck    sleevless
# 1  1212192089   Casual   Low     0.0   Large  Summer   o-neck        Petal
# 2  1190380701  vintage  High     0.0   Large  Autumn   o-neck         full
#
#      Material FabricType Decoration Pattern Type  Recommendation  Spring  \
# 0      cotton    chiffon    ruffles       animal               1  2660.0
# 1  microfiber        NaN    ruffles       animal               0   750.0
# 2    polyster        NaN        NaN        print               0     7.0
#
#     Summer  Winter   Autumn
# 0  13899.0  9658.0  26857.0
# 1   6216.0  6405.0  17311.0
# 2     40.0    28.0     82.0

# %%
np0['TotalSales'] = np0.apply(lambda x: x['Summer'] + x['Winter']+ x['Autumn']+ x['Spring'], axis=1)
np0.head(3)
# Out:
#      Dress_ID    Style Price  Rating    Size  Season NeckLine SleeveLength  \
# 0  1006032852     Sexy   Low     4.6  Medium  Summer   o-neck    sleevless
# 1  1212192089   Casual   Low     0.0   Large  Summer   o-neck        Petal
# 2  1190380701  vintage  High     0.0   Large  Autumn   o-neck         full
#
#      Material FabricType Decoration Pattern Type  Recommendation  Spring  \
# 0      cotton    chiffon    ruffles       animal               1  2660.0
# 1  microfiber        NaN    ruffles       animal               0   750.0
# 2    polyster        NaN        NaN        print               0     7.0
#
#     Summer  Winter   Autumn  TotalSales
# 0  13899.0  9658.0  26857.0     53074.0
# 1   6216.0  6405.0  17311.0     30682.0
# 2     40.0    28.0     82.0       157.0

# %%
# Group "Style" categories into "Others" which have less than 50000 sales across all the seasons.
np0.groupby(np0.Style).sum()[(np0.groupby(np0.Style).sum()).TotalSales<50000]
# Out:
#            Dress_ID  Rating  Recommendation  Spring  Summer  Winter  Autumn  \
# Style
# Others  10842564647    18.1               4   668.0  3471.0  3037.0  8883.0
#
#         TotalSales
# Style
# Others     16059.0

# %%
#replace with others 
np0.replace(np0.groupby(np0.Style).sum()[(np0.groupby(np0.Style).sum()).TotalSales<50000].index,'Others',inplace=True)

# %%
round(np0.Style.value_counts(normalize = True)*100.0 ,1)
# Out:
# Casual      45.7
# Sexy        13.8
# party       10.6
# cute         9.2
# vintage      5.2
# bohemian     4.8
# Brief        3.5
# work         3.5
# Others       2.1
# sexy         1.5
# Name: Style, dtype: float64

# %% [markdown]
# What is the percentage of “cute” and “Others” category in “Style” column in “Attribute DataSet” respectively?
# - 46%, 5%
# - 9%, 2.1%
# - 2.1%, 5%
# - 13.8%, 9%

# %%
# Calculate the percentage of each categories in the "Style" variable.
round(np0.Style.value_counts(normalize = True)*100.0,1).plot.barh()
plt.show()

# %%
np0.Autumn.describe()
# Out:
# count      477.000000
# mean      2837.616352
# std       5010.790796
# min          1.000000
# 25%        406.000000
# 50%       1329.000000
# 75%       3122.000000
# max      55532.000000
# Name: Autumn, dtype: float64

# %% [markdown]
# Similarly Club Neckline, SLeeve length categories into "Others" which have less than 50000 sales across all the seasons.

# %%
# Group "Neckline" categories into "Others" which have less than 50000 sales across all the seasons.
np0.replace(np0.groupby(np0.NeckLine).sum()[(np0.groupby(np0.NeckLine).sum()).TotalSales<50000].index,'Others',inplace=True)
np0.NeckLine.unique()
# Out:
# array(['o-neck', 'v-neck', 'boat-neck', 'Others', 'ruffled', nan],
#       dtype=object)

# %%
# Group "Sleeve length" categories into "Others" which have less than 50000 sales across all the seasons.
np0.replace(np0.groupby(np0.SleeveLength).sum()[(np0.groupby(np0.SleeveLength).sum()).TotalSales<50000].index,'Others',inplace=True)
np0.SleeveLength.unique()
# Out:
# array(['sleevless', 'Others', 'full', 'short', 'threequarter',
#        'halfsleeve', nan], dtype=object)

# %%
np0.columns
# Out:
# Index(['Dress_ID', 'Style', 'Price', 'Rating', 'Size', 'Season', 'NeckLine',
#        'SleeveLength', 'Material', 'FabricType', 'Decoration', 'Pattern Type',
#        'Recommendation', 'Spring', 'Summer', 'Winter', 'Autumn', 'TotalSales'],
#       dtype='object')

# %% [markdown]
# Club material, fabrictype, patterntype and decoration categories into "Others" which have less than 25000 sales across all the seasons

# %%
# Group "material" categories into "Others" which have less than 25000 sales across all the seasons.
np0.replace(np0.groupby(np0.Material).sum()[(np0.groupby(np0.Material).sum()).TotalSales<25000].index,'Others',inplace=True)

# %%
# Group "fabric type" categories into "Others" which have less than 25000 sales across all the seasons.
np0.replace(np0.groupby(np0.FabricType).sum()[(np0.groupby(np0.FabricType).sum()).TotalSales<25000].index,'Others',inplace=True)

# %%
# Group "patern type" categories into "Others" which have less than 25000 sales across all the seasons.
np0.replace(np0.groupby(np0['Pattern Type']).sum()[(np0.groupby(np0['Pattern Type']).sum()).TotalSales<25000].index,'Others',inplace=True)

# %%
# Group "decoration" categories into "Others" which have less than 25000 sales across all the seasons.
np0.replace(np0.groupby(np0.Decoration).sum()[(np0.groupby(np0.Decoration).sum()).TotalSales<25000].index,'Others',inplace=True)

# %% [markdown]
# ### Caregorical Ordered Univariate Analysis

# %% [markdown]
# Which of the following is an unordered variable in “Attribute DataSet”.
# - Style
# - Price
# - Season
# - Size

# %% [markdown]
# ### Numerical variable Univariate analysis:

# %% [markdown]
# What is the approximate difference between the maximum value and 75th percentile in “Autumn” column.
# - Approx 54000
# - Approx 55000
# - Approx 52000
# - Approx 50000

# %%
# Describe the numerical variale: "Autumn".
np0.Autumn.describe()
# Out:
# count      477.000000
# mean      2837.616352
# std       5010.790796
# min          1.000000
# 25%        406.000000
# 50%       1329.000000
# 75%       3122.000000
# max      55532.000000
# Name: Autumn, dtype: float64

# %%
# plot the boxplot of "Autumn" column.
sns.boxplot(np0.Autumn)
plt.show()

# %% [markdown]
# Which of the following season has the highest difference between the maximum value and 99th quantile of sales?
# - Winter
# - Summer
# - Spring
# - Autumn

# %%
# Find the maximum and 99th percentile of Winter season.
np0.Winter.max() - np0.Winter.quantile(.99)
# Out:
# 11469.969999999983

# %%
# Find the maximum and 99th percentile of Summer season.
np0.Summer.max() - np0.Summer.quantile(.99)
# Out:
# 21623.000000000007

# %%
# Find the maximum and 99th percentile of Spring season.
np0.Autumn.max() - np0.Autumn.quantile(.99)
# Out:
# 31528.19999999998

# %%
# Find the maximum and 99th percentile of Autumn season.
np0.Spring.max() - np0.Spring.quantile(.99)
# Out:
# 4717.12

# %% [markdown]
# ## Bivariate Analysis

# %% [markdown]
# ### Numerical- Categorical analysis

# %% [markdown]
# Which of the following “Price” category has the lowest average value of rating?
# - very-high
# - Medium
# - Low
# - High

# %%
# Find the Mean of Ratings for each Price category.
np0.groupby('Price').mean()
# Out:
#                Dress_ID    Rating  Recommendation      Spring       Summer  \
# Price
# Average    9.248940e+08  3.464167        0.366667  296.179167  1441.133333
# High       8.964353e+08  2.914286        0.428571  180.714286   803.809524
# Low        8.844119e+08  3.692121        0.430303  374.181818  1805.442424
# Medium     8.713896e+08  3.156667        0.633333  182.566667   842.866667
# very-high  8.357539e+08  3.123810        0.761905   56.238095   192.333333
#
#                 Winter       Autumn   TotalSales
# Price
# Average     997.545833  2831.594142  5542.451883
# High        513.047619  1498.428571  2996.000000
# Low        1234.521212  3544.969697  6959.115152
# Medium      544.966667  1597.233333  3167.633333
# very-high   134.238095   489.714286   872.523810

# %% [markdown]
# What is the median of the rating of “vintage” category in Style column?
# - 4.6
# - 4.7
# - 4.55
# - 0.00

# %%
# Find the median of Ratings for each Style category.
print(np0.groupby('Style')['Rating'].mean())
# Out:
# Style
# Brief       4.064706
# Casual      3.517808
# Others      1.810000
# Sexy        3.319697
# bohemian    3.873913
# cute        3.270455
# party       3.711765
# sexy        3.814286
# vintage     3.168000
# work        3.911765
# Name: Rating, dtype: float64

# %% [markdown]
# Which of the following season has the highest average value of sale for “Recommendation” value equals to 1.
# - Summer
# - Spring
# - Autumn
# - Winter

# %%
# Summer sale vs Recommendation.
np0.groupby('Recommendation')['Summer'].mean()
sns.boxplot(data = np0, x= 'Recommendation', y='Summer')
plt.show()

# %%
# Spring sale vs Recommendation.
np0.groupby('Recommendation')['Spring'].mean()
sns.boxplot(data = np0,x='Recommendation',y='Spring')
plt.show()

# %%
# Autumn sale vs Recommendation.
np0.groupby('Recommendation')['Autumn'].mean()
sns.boxplot(data= np0, x='Recommendation', y= 'Autumn')
plt.show()

# %%
# Winter sale vs Recommendation.
np0.groupby('Recommendation')['Winter'].mean()
sns.boxplot(data= np0,x='Recommendation',y='Winter')
plt.show()

# %% [markdown]
# ### Categorical categorical bivariate analysis

# %% [markdown]
# Which of the following size categories has the highest positive recommendations?
# - Medium and extra large
# - Extra large and small
# - Free and small
# - Free and medium

# %%
# Size vs Recommendation.
np0.groupby('Size')['Recommendation'].mean().plot.barh()
#np0.groupby('Size')['Recommendaton'].sum()
# Out:
# <AxesSubplot:ylabel='Size'>

# %% [markdown]
# ### Multivariate analysis

# %% [markdown]
# Which of the following pair of “Style” and “Price” category has the highest average of positive recommendations?
# - Price: medium and style: vintage
# - Price: medium and style: cute
# - Price: very high and style: party
# - Price: low and style: sexy

# %%
# plot the heat map of Style, price and Recommendation.
res = pd.pivot_table(data= np0, index= 'Style',columns= 'Price',values= 'Recommendation')
sns.heatmap(res,cmap="PiYG",annot=True)
plt.show()

# %% [markdown]
# Which of the following material type has no recommendation in summer and winter seasons?
# - Mix and Milksilk
# - Nylon and Rayon
# - Microfiber and Silk
# - Milksilk and Microfiber

# %%
# plot the heat map of Season, material and Recommendation.
res2 = pd.pivot_table(data= np0, index = 'Material', columns= 'Season', values= 'Recommendation')
sns.heatmap(res2,cmap='PiYG',annot = True)
plt.show()
