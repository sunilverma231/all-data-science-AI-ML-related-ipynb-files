# %%
c = 'Hello World' 
print(c[0])
# Out:
# H

# %%
L1 = [2,3,5,3,4,5,7,8]

L = []
for i in L1: 
    if i not in L: 
        L.append(i) 

print(L)
# Out:
# [2, 3, 5, 4, 7, 8]

# %%
sample = "abc@gmail.com" 
print(sample[:sample.find('@')])
# Out:
# abc

# %%
L1 = [2,3,5,3,4,5,7,8] 
print(list({i for i in L1}))
# Out:
# [2, 3, 4, 5, 7, 8]

# %%
Sunil = {"Name": "Sunil", "Gender": "Male"} 
Sunil
# Out:
# {'Name': 'Sunil', 'Gender': 'Male'}

# %%
D1 = {'Name': 'Rohit', 'College': 'IMT', 'Marks': {'M1': 56, 'DS': 54, 'Eng': 67}}
D1
# Out:
# {'Name': 'Rohit', 'College': 'IMT', 'Marks': {'M1': 56, 'DS': 54, 'Eng': 67}}

# %%
D1['College']
# Out:
# 'IMT'

# %%
D1['Marks']['DS']
# Out:
# 54

# %%
#editting in the dictionary 
D1['Marks']['DS']=64

# %%
D1
# Out:
# {'Name': 'Rohit', 'College': 'IMT', 'Marks': {'M1': 56, 'DS': 64, 'Eng': 67}}

# %%
D1.get('Name')
# Out:
# 'Rohit'

# %%
# adding a new eliment in dictionary 
D1['Age'] = 23

# %%
D1
# Out:
# {'Name': 'Rohit',
#  'College': 'IMT',
#  'Marks': {'M1': 56, 'DS': 64, 'Eng': 67},
#  'Age': 23}

# %%
del D1['College']

# %%
D1
# Out:
# {'Name': 'Rohit', 'Marks': {'M1': 56, 'DS': 64, 'Eng': 67}, 'Age': 23}

# %%
for i in D1: 
    print(i)
# Out:
# Name
# Marks
# Age

# %%
for i in D1: 
    print(D1[i])
# Out:
# Rohit
# {'M1': 56, 'DS': 64, 'Eng': 67}
# 23

# %%
for i in D1: 
    print(i,D1[i])
# Out:
# Name Rohit
# Marks {'M1': 56, 'DS': 64, 'Eng': 67}
# Age 23

# %%
def my_decorator(func): 
    def wrapper(): 
        print("Starting..") 
        func() 
        print("Finished!") 
    return wrapper

@my_decorator 
def greet(): 
    print("Good Morining!")
    
greet()
# Out:
# Starting..
# Good Morining!
# Finished!

# %%
a = '5'; print(int(a))
# Out:
# 5

# %%
a = 'Hello World' 
#list_a = list(a) 
print(list(i for i in a))
# Out:
# ['H', 'e', 'l', 'l', 'o', ' ', 'W', 'o', 'r', 'l', 'd']

# %%
str1 = 'I Love Data Science' 
print(str1.split())
# Out:
# ['I', 'Love', 'Data', 'Science']

# %%
str1_l = list(str1)
print(str1_l)
# Out:
# ['I', ' ', 'L', 'o', 'v', 'e', ' ', 'D', 'a', 't', 'a', ' ', 'S', 'c', 'i', 'e', 'n', 'c', 'e']

# %%
words = ['I', 'Love', 'Data', 'Science']
print(words[::-1])
# Out:
# ['Science', 'Data', 'Love', 'I']

# %%
a
# Out:
# 'Hello World'

# %%
print(a[::-1])
# Out:
# dlroW olleH

# %%
def reverse_string(s): 
    clean_s = s.lower().split()
    return clean_s[::-1]
list_1 = 'I Love Data Science' 
print(reverse_string(list_1))
# Out:
# ['science', 'data', 'love', 'i']

# %%
list_1 = [2,3,5,3,2,4,5,6]
print(list({i for i in list_1}))
# Out:
# [2, 3, 4, 5, 6]

# %%
import pandas as pd 
import numpy as np

# %%
arr1 = np.array([1,3,4,5,6]) 
arr2 = arr1[::-1] 
print(arr2)
# Out:
# [6 5 4 3 1]

# %%
arr3 = np.flip([1,3,5,6])
print(arr3)
# Out:
# [6 5 3 1]

# %%
arr_3 = np.array([2,3,5,4])
x = np .delete(arr_3,3) 
x
# Out:
# array([2, 3, 5])

# %%
arr_3[3] = 8
arr_3
# Out:
# array([2, 3, 5, 8])

# %%
list1 = ['w', 'a', 'w', 'b'] 
list_2 = ['e', 're', 'riting','log'] 
lst3 = [x + y for x,y in zip(list1, list_2)] 
print(lst3)
# Out:
# ['we', 'are', 'writing', 'blog']

# %%
print([x**2 for x in range(0,10)])
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
list_1 = [0, 1, 4, 9, 16, 25, 36, 49, 64, 81] 
lst_final = [] 
for x in lst: 
    lst_final.append(x*x) 
print(lst_final)
# Out:
# [1, 4, 9, 16]
