# %%
import ast

string = ['Mumbai', 'Delhi', 'Australia', 'Nigeria', 'USA', 'London', 'Canada']
k = int(input())

print(string[(k-1):])
# Out:
# 2
# ['Delhi', 'Australia', 'Nigeria', 'USA', 'London', 'Canada']

# %%
import ast 
string = "MuMbaI is in MAHArashTRA"
count = 0 
L = [] 
for x in string: 
    if x.isupper():
        count += 1 
        L.append(count)
else: 
    count = 0 
print(max(L))
# Out:
# 10

# %%
n = input()
x = n.replace(",", " ") 
flag = True 
for i in x: 
    if int(i)!=0 and int(i)%int(x)==0:
        flag = True 
    else: 
        flag = False 
        break 
if flag: 
    print("Happy Number") 
else: 
    print("Sad Number")
# Out:
# 66
# Sad Number

# %%
if True or True:
    if False and True or False:
        print('A')
    elif False and False or True and True:
        print('B')
    else:
        print('C')
else:
    print('D')
# Out:
# B

# %%
pin = input("Enter the pin: ") 
while pin != "1234":
    pin =  input("invalid pin please try again: ") 

print("Pin Validation successfull")
# Out:
# Enter the pin: 344
# invalid pin please try again: 1234
# Pin Validation successfull

# %%
L1 = [10, 20, 30, 24, 18]
L2 = [8, 14, 15, 20, 10]
L3=[]
for i in range(len(L2)): 
    L3.append(L2[i] - L1[1])
L3
# Out:
# [-12, -6, -5, 0, -10]

# %%
input_list = ['VARMA', 'raj', 'Gupta', 'SaNdeeP']
for i in input_list: 
    if 
    print(i)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/9m/ztkm5bns0x1b521x6wdpd4640000gn/T/ipykernel_33805/4055392880.py in <module>
#       1 input_list = ['VARMA', 'raj', 'Gupta', 'SaNdeeP']
# ----> 2 for i in input_list.isupper() == Ture:
#       3     print(i)
#
# AttributeError: 'list' object has no attribute 'isupper'

# %%
input_list = ['VARMA', 'raj', 'Gupta', 'SaNdeeP']
output=[] 
for i in range(len(input_list)): # length of input 
    output.append(input_list[i][0].upper() + input_list[i][1:].lower()) # first character as uppercase and remaining characters a lower case
print(output)
# Out:
# ['Varma', 'Raj', 'Gupta', 'Sandeep']

# %%
for n in range(1,20): 
    flag = True 
    for i in range(2,n)
       if n%i == 0:
        print(n, "is not a prime", i) 
        flag = False 
        break 
    if flag == True:
        print(n,"is prime")
# Out:
#   File "/var/folders/9m/ztkm5bns0x1b521x6wdpd4640000gn/T/ipykernel_33805/1583891911.py", line 3
#     for i in range(2,n)
#                        ^
# SyntaxError: invalid syntax

# %%
for n in range(1,20):
    flag = True
    for i in range(2,n):
        if n%i == 0:
            print(n, "is not a prime", i)
        flag = False
        break
    if flag == True:
        print(n,"is prime")
# Out:
# 1 is prime
# 2 is prime
# 4 is not a prime 2
# 6 is not a prime 2
# 8 is not a prime 2
# 10 is not a prime 2
# 12 is not a prime 2
# 14 is not a prime 2
# 16 is not a prime 2
# 18 is not a prime 2

# %%
data = [ ' Verma' ,  ' raj ' ,  ' Gupta ' ,  ' SaNdeeP ' ]
cleaned = [a.strip().capitalize() for a in data] 
print(cleaned)
# Out:
# ['Verma', 'Raj', 'Gupta', 'Sandeep']
